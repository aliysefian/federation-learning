# %%
import pandas as pd
import scipy
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# %%
df=pd.read_csv('./qoe_app_rating_dataset.csv')

# %%
df.describe()
# Out:
#        rating_timestamp_ms        rating  rating_session_start_timestamp_ms  \
# count         6.403600e+04  64036.000000                       6.403600e+04
# mean          1.511955e+12      4.334093                       1.511954e+12
# std           2.771878e+09      0.865034                       2.771791e+09
# min           1.502760e+12      1.000000                       1.502760e+12
# 25%           1.510140e+12      4.000000                       1.510140e+12
# 50%           1.511590e+12      5.000000                       1.511590e+12
# 75%           1.513970e+12      5.000000                       1.513970e+12
# max           1.519030e+12      5.000000                       1.519030e+12
#
#            lte_rsrq  wcdma_receive_power     wlan_rssi  \
# count  3.865300e+04         19888.000000  23480.000000
# mean   3.521839e+05           -85.861244    -58.140878
# std    3.653864e+07            18.499578     12.558083
# min   -2.147484e+09          -175.000000   -200.000000
# ...

# %%
df
# Out:
#        rating_timestamp_ms  rating  rating_session_start_timestamp_ms  \
# 0             1.513540e+12       3                       1.513540e+12
# 1             1.516280e+12       3                       1.516280e+12
# 2             1.510080e+12       5                       1.510080e+12
# 3             1.510430e+12       4                       1.510430e+12
# 4             1.510300e+12       5                       1.510300e+12
# ...                    ...     ...                                ...
# 64031         1.510480e+12       4                       1.510480e+12
# 64032         1.514610e+12       4                       1.514610e+12
# 64033         1.507010e+12       5                       1.507010e+12
# 64034         1.515050e+12       5                       1.515050e+12
# 64035         1.510220e+12       4                       1.510220e+12
#
#        lte_rsrq  wcdma_receive_power  wlan_rssi network_technology  \
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn import preprocessing

# %%
df["network_technology"].dropna
# Out:
# <bound method Series.dropna of 0          LTE
# 1          LTE
# 2          NaN
# 3          NaN
# 4        HSPA+
#          ...
# 64031    HSPA+
# 64032    HSPA+
# 64033      LTE
# 64034      LTE
# 64035      LTE
# Name: network_technology, Length: 64036, dtype: object>

# %%
le = preprocessing.LabelEncoder()
df["network_technology"]=le.fit_transform(df["network_technology"])
df["gender"]=le.fit_transform(df["gender"])
df["age_group"]=le.fit_transform(df["age_group"])
df["home_region_group"]=le.fit_transform(df["home_region_group"])
df["play_store_app_genre"]=le.fit_transform(df["play_store_app_genre"])
df["years_of_smartphone_use_group"]=le.fit_transform(df["years_of_smartphone_use_group"])
df["user_has_speed_limited_contract"]=le.fit_transform(df["user_has_speed_limited_contract"])
df["play_store_app_genre"]=le.fit_transform(df["play_store_app_genre"])

# %%
dt=df.drop(['rating_timestamp_ms', 'rating', 'rating_session_start_timestamp_ms','play_store_app_subgenre_for_family',
       'client_id'], axis=1, inplace=False)

# %%
df.columns
# Out:
# Index(['rating_timestamp_ms', 'rating', 'rating_session_start_timestamp_ms',
#        'lte_rsrq', 'wcdma_receive_power', 'wlan_rssi', 'network_technology',
#        'available_device_memory', 'download_throughout_bps',
#        'download_throughput_max_bps', 'download_bulk_throughput_max_bps',
#        'rtt_ms', 'connection_loss_ratio', 'user_has_speed_limited_contract',
#        'gender', 'age_group', 'years_of_smartphone_use_group',
#        'home_region_group', 'play_store_app_review_score',
#        'play_store_app_number_downloads', 'play_store_app_number_reviews',
#        'play_store_app_genre', 'play_store_app_subgenre_for_family',
#        'client_id'],
#       dtype='object')

# %%
dt.columns
# Out:
# Index(['lte_rsrq', 'wcdma_receive_power', 'wlan_rssi', 'network_technology',
#        'available_device_memory', 'download_throughout_bps',
#        'download_throughput_max_bps', 'download_bulk_throughput_max_bps',
#        'rtt_ms', 'connection_loss_ratio', 'user_has_speed_limited_contract',
#        'gender', 'age_group', 'years_of_smartphone_use_group',
#        'home_region_group', 'play_store_app_review_score',
#        'play_store_app_number_downloads', 'play_store_app_number_reviews',
#        'play_store_app_genre'],
#       dtype='object')

# %%
scaler = MinMaxScaler()
# transform data
scaled = scaler.fit_transform(dt)
scaled
# Out:
# array([[4.99999998e-01,            nan,            nan, ...,
#         9.99000001e-07, 3.67791991e-06, 3.55555556e-01],
#        [           nan,            nan,            nan, ...,
#         1.99999999e-01, 1.04620997e-01, 9.11111111e-01],
#        [           nan, 7.33870968e-01,            nan, ...,
#         1.99990000e-05, 3.33432476e-05, 6.22222222e-01],
#        ...,
#        [4.99999998e-01,            nan, 7.28723404e-01, ...,
#         1.99990000e-05, 1.87041585e-04, 6.22222222e-01],
#        [4.99999998e-01,            nan,            nan, ...,
#         1.99999999e-01, 3.55917826e-01, 9.55555556e-01],
#        [4.99999998e-01,            nan,            nan, ...,
#         1.99990000e-05, 3.76018917e-05, 5.33333333e-01]])

# %%
pd.DataFrame(scaled,columns=dt.columns)
# Out:
#        lte_rsrq  wcdma_receive_power  wlan_rssi  network_technology  \
# 0           0.5                  NaN        NaN            0.666667
# 1           NaN                  NaN        NaN            0.666667
# 2           NaN             0.733871        NaN            1.000000
# 3           NaN             1.000000        NaN            1.000000
# 4           NaN                  NaN        NaN            0.444444
# ...         ...                  ...        ...                 ...
# 64031       NaN                  NaN        NaN            0.444444
# 64032       NaN             0.653226        NaN            0.444444
# 64033       0.5                  NaN   0.728723            0.666667
# 64034       0.5                  NaN        NaN            0.666667
# 64035       0.5                  NaN        NaN            0.666667
#
#        available_device_memory  download_throughout_bps  \
# 0                     0.142784                      NaN
# ...

# %%
cols = ["lte_rsrq", "wcdma_receive_power","wlan_rssi"]
dt[cols]=dt[cols].fillna(dt.mode().iloc[0])
dt
# Out:
#        lte_rsrq  wcdma_receive_power  wlan_rssi  network_technology  \
# 0         -9.00                -51.0      -56.0                   6
# 1         -9.00                -51.0      -56.0                   6
# 2         -9.00                -84.0      -56.0                   9
# 3         -9.00                -51.0      -56.0                   9
# 4         -9.00                -51.0      -56.0                   4
# ...         ...                  ...        ...                 ...
# 64031     -9.00                -51.0      -56.0                   4
# 64032     -9.00                -94.0      -56.0                   4
# 64033     -8.35                -51.0      -63.0                   6
# 64034     -7.50                -51.0      -56.0                   6
# 64035     -9.75                -51.0      -56.0                   6
#
#        available_device_memory  download_throughout_bps  \
# 0                 8.518451e+08                      NaN
# ...

# %%
dt['rating']=df['rating']
dt['client_id']=df['client_id']

# %%
dt
# Out:
#        lte_rsrq  wcdma_receive_power  wlan_rssi  network_technology  \
# 0         -9.00                -51.0      -56.0                   6
# 1         -9.00                -51.0      -56.0                   6
# 2         -9.00                -84.0      -56.0                   9
# 3         -9.00                -51.0      -56.0                   9
# 4         -9.00                -51.0      -56.0                   4
# ...         ...                  ...        ...                 ...
# 64031     -9.00                -51.0      -56.0                   4
# 64032     -9.00                -94.0      -56.0                   4
# 64033     -8.35                -51.0      -63.0                   6
# 64034     -7.50                -51.0      -56.0                   6
# 64035     -9.75                -51.0      -56.0                   6
#
#        available_device_memory  download_throughout_bps  \
# 0                 8.518451e+08                      NaN
# ...

# %%
ss=dt.dropna()

# %%
df.isna().sum()
# Out:
# rating_timestamp_ms                       0
# rating                                    0
# rating_session_start_timestamp_ms         0
# lte_rsrq                              25383
# wcdma_receive_power                   44148
# wlan_rssi                             40556
# network_technology                        0
# available_device_memory                1046
# download_throughout_bps               18132
# download_throughput_max_bps           18132
# download_bulk_throughput_max_bps       6134
# rtt_ms                                 2414
# connection_loss_ratio                  1054
# user_has_speed_limited_contract           0
# gender                                    0
# age_group                                 0
# years_of_smartphone_use_group             0
# home_region_group                         0
# play_store_app_review_score               2
# play_store_app_number_downloads           0
# play_store_app_number_reviews             0
# ...

# %%
dt['rating']=df['rating']
dt['client_id']=df['client_id']

# %%
dt.isna().sum()
# Out:
# lte_rsrq                                0
# wcdma_receive_power                     0
# wlan_rssi                               0
# network_technology                      0
# available_device_memory              1046
# download_throughout_bps             18132
# download_throughput_max_bps         18132
# download_bulk_throughput_max_bps     6134
# rtt_ms                               2414
# connection_loss_ratio                1054
# user_has_speed_limited_contract         0
# gender                                  0
# age_group                               0
# years_of_smartphone_use_group           0
# home_region_group                       0
# play_store_app_review_score             2
# play_store_app_number_downloads         0
# play_store_app_number_reviews           0
# play_store_app_genre                    0
# rating                                  0
# client_id                               0
# dtype: int64

# %%
ss=dt.dropna()

# %%
ss
# Out:
#         lte_rsrq  wcdma_receive_power  wlan_rssi  network_technology  \
# 2      -9.000000                -84.0     -56.00                   9
# 5      -7.750000                -51.0     -56.00                   6
# 6      -8.916667                -51.0     -56.00                   6
# 8      -9.000000                -51.0     -56.00                   4
# 10     -7.840000                -51.0     -58.96                   8
# ...          ...                  ...        ...                 ...
# 64030 -10.450000                -51.0     -56.00                   6
# 64031  -9.000000                -51.0     -56.00                   4
# 64033  -8.350000                -51.0     -63.00                   6
# 64034  -7.500000                -51.0     -56.00                   6
# 64035  -9.750000                -51.0     -56.00                   6
#
#        available_device_memory  download_throughout_bps  \
# 2                 7.220961e+08             5.256422e+06
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
print(scaler.fit_transform(ss))

# %%
final=pd.DataFrame(scaler.fit_transform(ss),columns=dt.columns)

# %%
ss.to_csv('pre.csv')

# %%
ss.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\JAZB_E~1\AppData\Local\Temp/ipykernel_24524/952290182.py in <module>
# ----> 1 ss.data
#
# c:\users\jazb_esfahan\desktop\project\env\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'data'

# %%
df[(df.client_id == 1)]
# Out:
#        rating_timestamp_ms  rating  rating_session_start_timestamp_ms  \
# 820           1.504720e+12       4                       1.504720e+12
# 2408          1.505230e+12       3                       1.505230e+12
# 2793          1.504670e+12       3                       1.504670e+12
# 3785          1.504710e+12       5                       1.504710e+12
# 5120          1.504540e+12       5                       1.504540e+12
# ...                    ...     ...                                ...
# 61014         1.505240e+12       5                       1.505240e+12
# 61097         1.505820e+12       5                       1.505820e+12
# 62296         1.504720e+12       5                       1.504720e+12
# 63900         1.506070e+12       5                       1.506070e+12
# 63983         1.504990e+12       4                       1.504990e+12
#
#         lte_rsrq  wcdma_receive_power  wlan_rssi  network_technology  \
# ...

# %%
ss
# Out:
#         lte_rsrq  wcdma_receive_power  wlan_rssi  network_technology  \
# 2      -9.000000                -84.0     -56.00                   9
# 5      -7.750000                -51.0     -56.00                   6
# 6      -8.916667                -51.0     -56.00                   6
# 8      -9.000000                -51.0     -56.00                   4
# 10     -7.840000                -51.0     -58.96                   8
# ...          ...                  ...        ...                 ...
# 64030 -10.450000                -51.0     -56.00                   6
# 64031  -9.000000                -51.0     -56.00                   4
# 64033  -8.350000                -51.0     -63.00                   6
# 64034  -7.500000                -51.0     -56.00                   6
# 64035  -9.750000                -51.0     -56.00                   6
#
#        available_device_memory  download_throughout_bps  \
# 2                 7.220961e+08             5.256422e+06
# ...

# %%
df.to_numpy()[:,:-2].shape
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\JAZB_E~1\AppData\Local\Temp/ipykernel_24524/3900904471.py in <module>
# ----> 1 df[:,:-2].shape
#
# c:\users\jazb_esfahan\desktop\project\env\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# c:\users\jazb_esfahan\desktop\project\env\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3359             casted_key = self._maybe_cast_indexer(key)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# ...
